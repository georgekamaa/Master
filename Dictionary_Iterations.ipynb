# %% [markdown]
# <a href="https://colab.research.google.com/github/georgekamaa/Master/blob/main/Dictionary_Iterations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
my_skills = ['Python', 'SQL', 'Excel']

# Define data science job roles and required skills
job_roles = [
    {'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
    {'role': 'Data Scientist', 'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
    {'role': 'Machine Learning Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
    {'role': 'Data Engineer', 'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
    {'role': 'Business Intelligence Analyst', 'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
    {'role': 'Quantitative Analyst', 'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
    {'role': 'Operations Analyst', 'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
    {'role': 'Database Administrator', 'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
    {'role': 'AI Engineer', 'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
    {'role': 'Statistician', 'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}
]

job_roles
# Out:
# [{'role': 'Data Analyst', 'skills': ['Python', 'SQL', 'Excel']},
#  {'role': 'Data Scientist',
#   'skills': ['Python', 'R', 'Machine Learning', 'Deep Learning']},
#  {'role': 'Machine Learning Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Scikit-Learn']},
#  {'role': 'Data Engineer',
#   'skills': ['Python', 'Apache Spark', 'Hadoop', 'SQL']},
#  {'role': 'Business Intelligence Analyst',
#   'skills': ['Python', 'SQL', 'Tableau', 'Power BI', 'Excel']},
#  {'role': 'Quantitative Analyst',
#   'skills': ['R', 'Python', 'MATLAB', 'Statistics']},
#  {'role': 'Operations Analyst',
#   'skills': ['Python', 'SQL', 'Data Visualization', 'Process Improvement']},
#  {'role': 'Database Administrator',
#   'skills': ['SQL', 'Oracle', 'MySQL', 'Database Management']},
#  {'role': 'AI Engineer',
#   'skills': ['Python', 'TensorFlow', 'PyTorch', 'Computer Vision']},
#  {'role': 'Statistician',
#   'skills': ['R', 'SAS', 'Python', 'Statistical Modeling']}]

# %%
for job in job_roles:
  qualified = True

  for skill in my_skills:
    if skill not in job['skills']:
      qualified = False

  if qualified:
    print(job['role'])
# Out:
# Data Analyst
# Business Intelligence Analyst

# %%
# Getting to see if we can cook based on the Provided ingridients

my_ingridients = ['Eggs', 'Milk', 'Flour']

#The dictionary Iteration

recipes = [
    {'name': 'Pancakes', 'ingredients': ['Eggs', 'Milk', 'Flour']},
    {'name': 'Omelette', 'ingredients': ['Eggs', 'Milk', 'Cheese']},
    {'name': 'Cake', 'ingredients': ['Eggs', 'Milk', 'Flour', 'Sugar']}
]



for recipe in recipes:
    can_cook = True

    for item in my_ingridients:
      if item not in recipe['ingredients']:
        can_cook = False

    if can_cook:
      print(recipe['name'])
# Out:
# Pancakes
# Cake

# %%
#Getting to see my type of Movie

my_genres = ['Action', 'Comedy', 'Sci-Fi']

movies = [
    {'title': 'Star Adventure', 'genres': ['Action', 'Sci-Fi']},
    {'title': 'Funny Life', 'genres': ['Comedy', 'Drama']},
    {'title': 'Epic Saga', 'genres': ['Action', 'Comedy', 'Sci-Fi']},
    {'title': 'Romantic Evening', 'genres': ['Romance', 'Drama']}
]


for movie in movies:
  can_watch = True

  for genre in my_genres:
    if genre not in movie['genres']:
      can_watch = False

  if can_watch:
    print(movie['title'])
# Out:
# Epic Saga
