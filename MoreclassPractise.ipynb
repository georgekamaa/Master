# %% [markdown]
# <a href="https://colab.research.google.com/github/georgekamaa/Master/blob/main/MoreclassPractise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BaseSalary:
  def __init__(self, base_salary, bonus_rate = 0.1, symbol = "$"):
    self.base_salary = base_salary
    self.bonus_rate = bonus_rate
    self.symbol = symbol
    self.total_salary = base_salary * (1 + bonus_rate)
    self.bonus = (self.total_salary - base_salary) / base_salary

  def __repr__(self):
    return f"{self.symbol}{self.base_salary:,.0f}"

  def calculate_salary(self):
    return f"{self.symbol}{self.total_salary:,.0f}"

  def calculate_bonus(self):
    return f"{self.symbol}{self.bonus:,.0f}"

# %%
salary.calculate_salary()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2137082634.py in <cell line: 0>()
# ----> 1 salary.calculate_salary()
#
# AttributeError: 'BaseSalary' object has no attribute 'calculate_salary'
